# %% [markdown]
# ## Location
# 32.4753° N, 97.0103° W
#
# ## Population
# 33,532
# [Midlothian, TX Population](https://www.census.gov/quickfacts/midlothiancitytexas)
#
# ## Landmark
# ![hawkins%20house.jpeg](attachment:hawkins%20house.jpeg)
# A log cabin with an earthen floor was the community's first school, church, and community hall.
