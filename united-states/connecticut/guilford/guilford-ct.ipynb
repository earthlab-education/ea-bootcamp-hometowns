# %% [markdown]
# # Guilford, Connecticut
#
# ## Location: 41.2889° N, 72.6744° W
#
# ## Population (2019 est.): 22,133
# https://www.census.gov/quickfacts/guilfordtownnewhavencountyconnecticut
#
# ## Landmark: Bishop's Orchards - fifth generation family farm market and apple orchard
# https://bishopsorchards.com/farm-market/about/
#
# ![image.png](attachment:image.png)
