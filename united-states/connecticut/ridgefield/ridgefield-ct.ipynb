# %% [markdown]
# # Location

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="my_user_agent")
city ="Ridgefield"
state ="Connecticut"
country ="United States"
loc = geolocator.geocode(city+','+state+','+ country)
print("latitude is :-" ,loc.latitude,"\nlongtitude is:-" ,loc.longitude)
# Out:
# latitude is :- 41.2814842
# longtitude is:- -73.4981792

# %% [markdown]
# # Population

# %%
ridgefield_population = 25033
print(ridgefield_population)
#https://www.census.gov/quickfacts/fact/table/ridgefieldtownfairfieldcountyconnecticut/POP010220
# Out:
# 25033

# %% [markdown]
# # Landmark

# %%
print("Weir Barn is part of the Weir Farm National Historical Park in Ridgefield, CT ")
from IPython import display
display.Image('https://www.nps.gov/common/uploads/cropped_image/primary/6594081C-A8AB-94F0-B82883E9EB61BF5E.jpg')
# Out:
# Weir Barn is part of the Weir Farm National Historical Park in Ridgefield, CT
