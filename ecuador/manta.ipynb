# %% [markdown]
# ## Location
# 0.9677° S 80.7089° W
#
# ## Population
# 217,553 (2020, city)
# https://en.wikipedia.org/wiki/Manta,_Ecuador
#
# ## Landmark
# Panama Hat Girl
# ![panama-hat-girl.jpg](attachment:panama-hat-girl.jpg)
# Monument to the Panama hat makers of Ecuador
